# %%
import sys
from pathlib import Path

# add project root to sys.path
root = "../"
sys.path.append(str(root))

from data.luna_dataset import LunaDataset

# %%
from torch.utils.data.dataloader import DataLoader

stride = 10
train_dataset = LunaDataset(validate_stride=stride, validate=False)

train_dl = DataLoader(
    dataset=train_dataset,
    batch_size=32,
    num_workers=6,
    pin_memory=True,
)

# %%
from config import MHD_INDEX

print("Number of keys:", len(MHD_INDEX))
print("First 5 keys:", list(MHD_INDEX.keys())[:5])
# Out:
# Number of keys: 888
# First 5 keys: ['1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260', '1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492', '1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', '1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674661221381920536987', '1.3.6.1.4.1.14519.5.2.1.6279.6001.122763913896761494371822656720']

# %%
import timeit

start = timeit.default_timer()
i = 0
for sample in train_dataset:
    if i == 100:
        break

    _, _, series_uid, _ = sample
    print(f"current series_uid: {series_uid}")
    i += 1

end = timeit.default_timer()

print(f"time elapsed = {end - start}s")
# Out:
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# current series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860
# ...
